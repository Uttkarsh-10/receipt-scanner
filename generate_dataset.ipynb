# %%
food = [
    ("Dominos","Pizza"),
    ("McDonalds","Burger"),
    ("Starbucks","Coffee")
]

transport = [
    ("Uber","Ride"),
    ("Ola","Taxi")
]

shopping = [
    ("Amazon","Headphones"),
    ("Flipkart","Mobile")
]
